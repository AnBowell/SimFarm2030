# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import pandas as pd
from scipy.stats import beta 
head =[]
tail = []
for i in range(1,1000):
    size = 10000
    y = np.random.randint(2, size=size)
    headscounter,tailscounter = 0,0
    for item in y:
        if item == 1:
            headscounter += 1
        else:
            tailscounter += 2
    head.append(headscounter)
    tail.append(tailscounter)

x = np.arange(1,1000,1)
plt.scatter(x,head)
plt.show()
mu, std = norm.fit(head)
plt.hist(head, bins=30, density=True, alpha=0.6, color='r')
print(mu,sigma)


xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = " Step Fit results: Average = %.0f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()
# Out:
# 5002.624624624625 49.98428003125869

# %%
x = np.arange(0,1,0.01)
means = []
vars =[]
skews =[]
kurts =[]
for item,item2 in zip(head,tail):
    mean, var, skew, kurt = beta.stats(item, item2, moments='mvsk')
    PDF = beta.pdf(x,item,item2)
    plt.plot(x,PDF)
    means.append(mean)
    vars.append(var)
    skews.append(skew)
    kurts.append(kurt)
plt.show()
print(np.mean(means),np.mean(vars),np.mean(skews),np.mean(kurts))
# Out:
# 0.3335815978427021 1.4821102606023352e-05 0.01152872370261453 5.441915720473804
