# %% [markdown]
# # Bayesian Monthly Sensitivity Model
#
# ### Adapted for SimFarm2030

# %%
import pandas as pd
import pylab as plt
import numpy as np
import seaborn as sns
import pystan
# %matplotlib inline

# %%
# Compile model
sm=pystan.StanModel(file='stan/BMSM-simp.stan')
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_e7839d65b913f1005fc3976af2843100 NOW.
# C:\Users\Andrew\Anaconda3\lib\site-packages\Cython\Compiler\Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Andrew\AppData\Local\Temp\tmpnzmde1be\stanfit4anon_model_e7839d65b913f1005fc3976af2843100_3516908443650320811.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
templists,rainlists,yieldlist =[],[],[]

for counter in range(1,7):
    templists.append(np.load('data/Temps'+str(counter)+'.npy'))
    
for counter in range(1,7):
    rainlists.append(np.load('data/Rain'+str(counter)+'.npy'))

for counter in range(1,7):
    yieldlist.append(np.load('data/Yield'+str(counter)+'.npy'))
    
rainlists = np.array(rainlists)
templists = np.array(templists)
yieldlist= np.array(yieldlist)

templists = templists.reshape(6,int(len(templists[0])/12),12)



rainlists = rainlists.reshape(6,int(len(rainlists[0])/12),12)

data={
    'n_regions':2,
    'n_years':8,
    'd_temp':templists[0:2],
    'd_yields':yieldlist[0:2],
}

# %%
fit=sm.sampling(data=data,chains=4,iter=1000,verbose=True,control={'max_treedepth': 14})
# Out:
# WARNING:pystan:1680 of 2000 iterations saturated the maximum tree depth of 14 (84.0%)
# WARNING:pystan:Run again with max_treedepth larger than 14 to avoid saturation

# %%
fit
# Out:
# Inference for Stan model: anon_model_e7839d65b913f1005fc3976af2843100.
# 4 chains, each with iter=1000; warmup=500; thin=1;
# post-warmup draws per chain=500, total post-warmup draws=2000.
#
#                      mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# s_temp[1,1]          4.95    3.01  50.07 -95.56 -29.98   6.43  39.85 101.78    276   1.02
# s_temp[2,1]         -0.77    4.09  70.61 -147.5 -48.39   1.69   46.3 136.22    298   1.02
# s_temp[1,2]         -3.15    3.81  70.85 -135.7 -52.24  -3.21  46.62 133.78    346   1.01
# s_temp[2,2]         -5.17    2.88  65.24 -142.5 -47.76  -3.58  38.07 118.44    515    1.0
# s_temp[1,3]          1.35    3.45  52.06 -96.57 -33.81   0.66  35.61 106.29    227   1.01
# s_temp[2,3]          4.19    2.47  46.44  -88.6 -26.38   4.94  36.85  92.07    354   1.01
# s_temp[1,4]          2.02    4.66   65.8 -129.5 -42.91   3.25  47.42  125.5    199   1.03
# s_temp[2,4]          4.51    3.86   70.8 -137.4 -41.72   7.16  54.19 138.78    336   1.01
# s_temp[1,5]         -6.34    3.92  82.35 -162.4 -63.12  -8.88  51.76  152.5    440   1.01
# s_temp[2,5]          2.07    4.02  89.49 -170.1  -59.0   0.36   59.0 178.97    495   1.01
# s_temp[1,6]          5.99    3.97   75.3 -147.4 -45.88   7.46  59.94 147.45    360   1.01
# s_temp[2,6]         -4.93    3.28  63.19 -128.2 -49.39  -6.29  38.43  120.0    370   1.01
# s_temp[1,7]         -2.36    1.74  29.03 -56.59 -23.16  -2.75  17.65  55.19    280   1.01
# s_temp[2,7]          2.01    2.55  43.96 -86.24 -27.55   3.26  32.21  89.73    298   1.01
# s_temp[1,8]         -0.62    2.58  53.29 -106.5 -36.87  -0.64  36.63  96.97    426   1.01
# s_temp[2,8]         -1.69    2.02  31.57 -65.86  -23.5   0.14  19.58  56.35    244   1.02
# s_temp[1,9]         -0.09    3.06  39.87 -77.39 -26.73  -2.87  25.37  82.56    170   1.02
# s_temp[2,9]          0.07    1.82  33.74 -67.43 -23.12  -0.91  21.44  66.71    344   1.01
# s_temp[1,10]          3.0    3.86  52.54 -95.13 -32.86   0.61  36.89 108.92    186   1.01
# s_temp[2,10]         2.03    3.59  72.33 -141.4 -45.97   3.21  47.63 151.22    406    1.0
# s_temp[1,11]        -3.22     4.1  65.41 -127.6 -47.63  -1.73  40.84 122.98    254   1.02
# s_temp[2,11]        -3.25    3.08  58.34 -114.5 -44.26  -3.17  36.31 111.68    359   1.01
# s_temp[1,12]          1.4    1.66  28.63 -52.83 -18.35   0.44  21.62  58.76    299   1.01
# s_temp[2,12]         2.68    1.52  27.73 -52.08  -15.9   2.65  20.52  57.22    332   1.01
# d_yields_pred[1,1]   7.98    0.03   1.35   5.28   7.08   7.99    8.9  10.63   1809    1.0
# d_yields_pred[2,1]  11.49    0.03   1.38   8.71  10.53  11.49  12.48  14.15   2126    1.0
# d_yields_pred[1,2]  10.56    0.03   1.46   7.78   9.56  10.56  11.56  13.38   2006    1.0
# d_yields_pred[2,2]  13.92    0.03   1.43  11.08  12.96  13.91  14.86  16.79   2106    1.0
# d_yields_pred[1,3]  12.89    0.03   1.39  10.23  11.93   12.9  13.91  15.44   1785    1.0
# d_yields_pred[2,3]   8.68    0.03   1.43   5.85   7.74   8.69   9.65  11.53   2029    1.0
# d_yields_pred[1,4]  11.14    0.03   1.43    8.4  10.17  11.14  12.14  13.92   1926    1.0
# d_yields_pred[2,4]   9.49    0.03   1.41    6.8   8.51   9.49  10.43   12.3   1956    1.0
# d_yields_pred[1,5]  12.53    0.03   1.39   9.64  11.65  12.55  13.42  15.25   2066    1.0
# d_yields_pred[2,5]  13.34    0.03   1.37  10.58  12.43  13.35  14.27  15.92   1722    1.0
# d_yields_pred[1,6]  11.67    0.03   1.46   8.77  10.71  11.69  12.64  14.55   2032    1.0
# d_yields_pred[2,6]  14.89    0.03   1.42  12.19  13.93  14.86  15.81  17.76   2091    1.0
# d_yields_pred[1,7]  11.66    0.03   1.37   8.98  10.78  11.65  12.62  14.27   1833    1.0
# d_yields_pred[2,7]  11.84    0.03   1.47   9.14  10.76  11.82  12.88  14.89   2057    1.0
# d_yields_pred[1,8]  11.83    0.03    1.4   9.16  10.84  11.86  12.76  14.53   1946    1.0
# d_yields_pred[2,8]  13.08    0.03   1.46  10.24  12.09  13.05  14.03  15.93   2183    1.0
# tmp                 13.07    0.02   1.02  11.06   12.4  13.08  13.75  15.03   2178    1.0
# lp__               -12.17    0.13   3.36 -19.97 -14.17 -11.83  -9.69  -6.37    679    1.0
#
# Samples were drawn using NUTS at Wed Aug 14 16:18:50 2019.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
# carry out some diagnostic checks on fit
import stan_utility
stan_utility.check_div(fit)
stan_utility.check_energy(fit)
stan_utility.check_treedepth(fit)
# Out:
# 0.0 of 2000 iterations ended with a divergence (0.0%)
# 33 of 2000 iterations saturated the maximum tree depth of 10 (1.65%)
# Run again with max_depth set to a larger value to avoid saturation

# %%
samples=fit.extract()

# %%
plt.figure(figsize=(10,10))
plt.violinplot(samples['s_temp'][:,0,:]);
plt.violinplot(samples['s_temp'][:,1,:]);
plt.xticks(range(1,13),maize_temp.columns[1:]);

# %%
for s in range(0,2000,100):
    plt.plot(range(2010,2018),samples['d_yields_pred'][s,0,:].T,alpha=0.5)

# %%
plt.figure(figsize=(10,5))
plt.violinplot(samples['d_yields_pred'][:,0,:],showextrema=False);
plt.xticks(range(1,9),np.arange(2010,2018),rotation=90);
plt.plot(range(1,9),fit.data['d_yields'][0,:])

# %%
plt.figure(figsize=(10,5))
plt.violinplot(samples['d_yields_pred'][:,1,:],showextrema=False);
plt.xticks(range(1,9),np.arange(2010,2018),rotation=90);
plt.plot(range(1,9),fit.data['d_yields'][1,:])

# %%
fit.data['d_yields'].shape
# Out:
# (2, 35)
