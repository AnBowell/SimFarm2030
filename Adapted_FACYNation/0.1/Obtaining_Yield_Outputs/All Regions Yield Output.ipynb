# %% [markdown]
# ### Yield Outputs with correlation

# %%
import pandas as pd
import pylab as plt
import numpy as np
import seaborn as sns
import pystan
# %matplotlib inline



gm2 = pystan.StanModel(file='./stan/2d-gaussian_with_correlation.stan')


years = np.arange(1,7,1)
combinations = []
for counter in range(0,6):
    combinations.append(np.delete(years,counter))
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_2df05908660c977a9152ef2888fc2e93 NOW.
# C:\Users\Andrew\Anaconda3\lib\site-packages\Cython\Compiler\Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Andrew\AppData\Local\Temp\tmp_dqa8m75\stanfit4anon_model_2df05908660c977a9152ef2888fc2e93_2825274732025885618.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
loopcounter = 0
Residuals = []
for item in combinations:
    loopcounter +=1 
    templists,rainlists,yieldlist =[],[],[]

    for tempss in item:
        templists.append(np.load('data/Temps'+str(tempss)+'.npy'))

    for rainss in item:
        rainlists.append(np.load('data/Rain'+str(rainss)+'.npy'))

    for yieldss in item:
        yieldlist.append(np.load('data/Yield'+str(yieldss)+'.npy'))

    rainlists = np.array(rainlists)
    templists = np.array(templists)
    yieldlist= np.array(yieldlist)

    templists = templists.reshape(5,int(len(templists[0])/12),12)

    templists= templists[:,:,4:10]

    rainlists = rainlists.reshape(5,int(len(rainlists[0])/12),12)
    rainlists= rainlists[:,:,4:10]

    data2={
        'n_regions':5,
        'n_years':8,
        'd_temp':templists,
        'd_precip':rainlists,
        'd_yields':yieldlist,
        'n_gf':40,
        'temp':np.arange(0,40,1),
        'precip':np.arange(0,200,5)
    }
    fit=gm2.sampling(data=data2,chains=4,iter=1000,verbose=True,seed=1308)


    samples=fit.extract()


    #plt.figure(figsize=(10,10))
    for i in range(0,2000,10):
        plt.plot(fit.data['temp'],samples['fdy1'][i,:],alpha=0.1, c='b')
    plt.xlabel('Temperature')
    plt.ylabel(r'$dy$')
    #plt.title('Growth Curve')
    plt.show()


    #plt.figure(figsize=(10,10))
    for i in range(0,2000,10):
        plt.plot(fit.data['precip'],samples['fdy2'][i,:],alpha=0.1, c='b')
    plt.xlabel('precipitation')
    plt.ylabel(r'$dy$')
    plt.show()
    #plt.title('Growth Curve')

    from numpy import exp,arange
    from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show


    fig, ax = plt.subplots()

    t1, t2 = 0., 35.
    p1, p2 = 0., 250.
    x = np.linspace(t1,t2,100)
    y = np.linspace(p1,p2,100)
    X,Y = meshgrid(x, y) # grid of point

    def yield_equal2(temp, precip, mu_t, sigma_t, mu_p, sigma_p, rho, norm):
        """Take six months of T and P and return yield for given params.

        This should be identical to the function in the STAN model
        """
        temp_6m = np.full(6, temp)
        precip_6m = np.full(6, precip)
        if len(norm) == 1:
            norm = norm * np.ones(6)
        dy = np.zeros(6)
        for month in np.arange(6):
            dy[month] = norm[month]*np.exp(-(1/(2 - 2*rho**2)) *( np.square((temp_6m[month]    - mu_t)/sigma_t) 
                                                               + np.square((precip_6m[month] - mu_p)/sigma_p) 
                                                               - (2*rho*(temp_6m[month]    - mu_t)
                                                                       *(precip_6m[month] - mu_p)
                                                                 )
                                                                  /(sigma_t*sigma_p)
                                                               )
                                          )
        return np.sum(dy)



    def z_func(X,Y):
        return yield_equal2(X, Y, float(np.mean(samples['mu_t'])), float(np.mean(samples['sigma_t'])), float(np.mean(samples['mu_p'])),
           float(np.mean(samples['sigma_p'])), float(np.mean(samples['rho'])), [float(np.mean(samples['norm']))])


    z_func = np.vectorize(z_func)
    #Lets use the median

    Z = z_func(X, Y) # evaluation of the function on the grid

    im = ax.imshow(np.flip(Z, axis=0),cmap="viridis", extent=[t1,t2,p1,p2], aspect="auto") # drawing the function

    cbar = fig.colorbar(im) # adding the colobar on the right
    cbar.set_label('Yield [tonnes ha$^{-1}$]')
    # latex fashion title
    #title('$z=(1-x^2+y^3) e^{-(x^2+y^2)/2}$')

    ax.set_xlabel('T (Celsius)')
    ax.set_ylabel('Monthly precipitation (mm)')
    #plt.savefig('./figs/2d_2.pdf')

    plt.show()

    

    TestTemps = np.load('data/Temps'+str(loopcounter)+'.npy')
    TestRains = np.load('data/Rain'+str(loopcounter)+'.npy')
    TestYield = np.load('data/Yield'+str(loopcounter)+'.npy')



    TestRains = np.split(TestRains,len(TestRains)/12)
    TestTemps = np.split(TestTemps,len(TestTemps)/12)

    xindex,yindex = [],[]


    for Rain,Temp,Yield in zip(TestRains,TestTemps,TestYield):

        print(Yield, ' Actual Yield')

        xidx = (np.abs(x - np.mean(Temp[4:10]))).argmin()

        yidx = (np.abs(y - np.mean(Rain[4:10]))).argmin()

        print(np.mean(Temp[4:10]),np.mean(Rain[4:10]), 'Average temp/Rain')
        #print(x[xidx],y[yidx], 'Closest value')
        print(Z[yidx,xidx], ' Predicted Yield')
        print('Difference = ', Yield-Z[yidx,xidx])
        xindex.append(x[xidx])
        yindex.append(y[yidx])
        Residuals.append(Yield-Z[yidx,xidx])
    print('Region',loopcounter, 'Done. Trained with', item)

plt.title('Residuals plot')
plt.scatter(np.arange(1,(8*6)+1),Residuals)
print(np.mean(Residuals))
plt.show()
# Out:
# 7.95  Actual Yield
# 14.414647104349777 54.766995740921494 Average temp/Rain
# 14.462535110018463  Predicted Yield
# Difference =  -6.5125351100184625
# 10.51  Actual Yield
# 14.944484391925714 41.961273796518434 Average temp/Rain
# 12.866755241886796  Predicted Yield
# Difference =  -2.3567552418867965
# 12.89  Actual Yield
# 13.998616599742618 69.58885484800027 Average temp/Rain
# 15.269558898180334  Predicted Yield
# Difference =  -2.379558898180333
# 11.18  Actual Yield
# 14.623573173295455 45.43978041008618 Average temp/Rain
# 13.157231824637012  Predicted Yield
# Difference =  -1.9772318246370126
# 12.54  Actual Yield
# 15.33100428710746 63.277669398553265 Average temp/Rain
# 15.182491946948108  Predicted Yield
# Difference =  -2.642491946948109
# 11.69  Actual Yield
# 14.185968893313694 54.55563823988985 Average temp/Rain
# 14.3159429114997  Predicted Yield
# Difference =  -2.625942911499701
# 11.68  Actual Yield
# 15.50223976964532 48.701213177092306 Average temp/Rain
# 13.649138184623895  Predicted Yield
# Difference =  -1.9691381846238958
# 11.82  Actual Yield
# 15.356184469826596 53.59610287794939 Average temp/Rain
# 14.30425982869394  Predicted Yield
# Difference =  -2.48425982869394
# Region 1 Done. Trained with [2 3 4 5 6]
# 11.5  Actual Yield
# 12.881321782750886 51.98160493688618 Average temp/Rain
# 11.306210654266092  Predicted Yield
# Difference =  0.19378934573390794
# 13.95  Actual Yield
# 13.112154925132394 61.005736185307825 Average temp/Rain
# 12.834882193932732  Predicted Yield
# Difference =  1.1151178060672677
# 8.66  Actual Yield
# 12.183469928728114 97.20990950997668 Average temp/Rain
# 12.82988098108954  Predicted Yield
# Difference =  -4.169880981089539
# 9.47  Actual Yield
# 13.493582989779258 65.51658264564786 Average temp/Rain
# 13.874054376581265  Predicted Yield
# Difference =  -4.404054376581264
# 13.32  Actual Yield
# 13.588810864841983 55.380299610147354 Average temp/Rain
# 12.607102908893179  Predicted Yield
# Difference =  0.7128970911068215
# 14.88  Actual Yield
# 12.3790636998071 63.443246581933806 Average temp/Rain
# 12.129824673498618  Predicted Yield
# Difference =  2.750175326501383
# 11.82  Actual Yield
# 13.59990382436358 45.38418842095896 Average temp/Rain
# 10.99616972713528  Predicted Yield
# Difference =  0.8238302728647202
# 13.04  Actual Yield
# 13.605862276968063 65.08961631652302 Average temp/Rain
# 13.874054376581265  Predicted Yield
# Difference =  -0.8340543765812658
# Region 2 Done. Trained with [1 3 4 5 6]
# 12.3  Actual Yield
# 11.397465002617087 77.5035100116798 Average temp/Rain
# 14.020845239730214  Predicted Yield
# Difference =  -1.7208452397302132
# 9.46  Actual Yield
# 11.695932647095654 83.13994104979277 Average temp/Rain
# 14.117799666101325  Predicted Yield
# Difference =  -4.657799666101324
# 7.17  Actual Yield
# 10.476859034461926 75.08584734806414 Average temp/Rain
# 13.220767144817218  Predicted Yield
# Difference =  -6.050767144817218
# 7.98  Actual Yield
# 12.279263038324778 58.02672054829355 Average temp/Rain
# 14.266913550961823  Predicted Yield
# Difference =  -6.286913550961822
# 10.58  Actual Yield
# 12.403748316992013 82.26428087049909 Average temp/Rain
# 14.58508207961454  Predicted Yield
# Difference =  -4.0050820796145405
# 10.86  Actual Yield
# 11.301104918511216 78.8301483137592 Average temp/Rain
# 14.020845239730214  Predicted Yield
# Difference =  -3.1608452397302145
# 9.66  Actual Yield
# 12.170730190505772 73.41229519354555 Average temp/Rain
# 14.746324620810281  Predicted Yield
# Difference =  -5.086324620810281
# 11.4  Actual Yield
# 12.316422886833756 88.01444743305717 Average temp/Rain
# 14.10664214665287  Predicted Yield
# Difference =  -2.70664214665287
# Region 3 Done. Trained with [1 2 4 5 6]
# 11.81  Actual Yield
# 14.085915110009532 53.8150708720396 Average temp/Rain
# 15.265680565251486  Predicted Yield
# Difference =  -3.4556805652514857
# 7.59  Actual Yield
# 14.527264359717769 39.463266010503354 Average temp/Rain
# 13.840655781193254  Predicted Yield
# Difference =  -6.250655781193254
# 10.68  Actual Yield
# 13.422502344242611 73.52649934526958 Average temp/Rain
# 15.414126792743065  Predicted Yield
# Difference =  -4.734126792743066
# 10.73  Actual Yield
# 14.45880658787329 55.99576505975614 Average temp/Rain
# 15.589374658601708  Predicted Yield
# Difference =  -4.859374658601707
# 11.15  Actual Yield
# 14.779819007418396 60.17011185874616 Average temp/Rain
# 15.83648022922286  Predicted Yield
# Difference =  -4.686480229222859
# 9.69  Actual Yield
# 13.70231505502669 51.705216022427635 Average temp/Rain
# 14.790305437686495  Predicted Yield
# Difference =  -5.100305437686496
# 11.1  Actual Yield
# 14.779252670434774 51.99145212469265 Average temp/Rain
# 15.444353024204991  Predicted Yield
# Difference =  -4.344353024204992
# 11.66  Actual Yield
# 14.80650772022427 59.22250971806701 Average temp/Rain
# 15.751238768245925  Predicted Yield
# Difference =  -4.091238768245924
# Region 4 Done. Trained with [1 2 3 5 6]
# 15.1  Actual Yield
# 14.198538275800827 52.94545204909298 Average temp/Rain
# 13.649483939202185  Predicted Yield
# Difference =  1.4505160607978151
# 13.54  Actual Yield
# 14.589825666220515 43.137771619386164 Average temp/Rain
# 11.949906171895865  Predicted Yield
# Difference =  1.5900938281041341
# 11.4  Actual Yield
# 14.065022841433363 81.8528400594001 Average temp/Rain
# 16.125122309162617  Predicted Yield
# Difference =  -4.725122309162616
# 10.91  Actual Yield
# 14.548827744717196 58.921625219466584 Average temp/Rain
# 14.660156268647501  Predicted Yield
# Difference =  -3.750156268647501
# 10.41  Actual Yield
# 15.198138412051868 59.23050963161179 Average temp/Rain
# 14.894942732855244  Predicted Yield
# Difference =  -4.484942732855243
# 10.71  Actual Yield
# 14.073413018917192 63.610225565641485 Average temp/Rain
# 15.114630143817212  Predicted Yield
# Difference =  -4.4046301438172115
# 10.71  Actual Yield
# 15.270283108698948 41.85423852542796 Average temp/Rain
# 12.18260711114834  Predicted Yield
# Difference =  -1.4726071111483385
# 10.57  Actual Yield
# 15.18030497476313 58.883721533506936 Average temp/Rain
# 14.894942732855244  Predicted Yield
# Difference =  -4.324942732855243
# Region 5 Done. Trained with [1 2 3 4 6]
# 9.92  Actual Yield
# 14.358576031711706 51.07441986976094 Average temp/Rain
# 14.025477132406142  Predicted Yield
# Difference =  -4.105477132406142
# 9.97  Actual Yield
# 14.732916462941553 40.66096251814372 Average temp/Rain
# 12.408013617948296  Predicted Yield
# Difference =  -2.438013617948295
# 11.4  Actual Yield
# 13.947335751373886 73.02363248258295 Average temp/Rain
# 15.641532045752667  Predicted Yield
# Difference =  -4.241532045752667
# 10.62  Actual Yield
# 14.567919942128436 50.78099782548899 Average temp/Rain
# 14.025477132406142  Predicted Yield
# Difference =  -3.4054771324061424
# 12.79  Actual Yield
# 15.239959757321992 66.18021898889897 Average temp/Rain
# 15.692410355380146  Predicted Yield
# Difference =  -2.9024103553801464
# 10.75  Actual Yield
# 14.083599775507329 51.59559642377991 Average temp/Rain
# 13.862502161876794  Predicted Yield
# Difference =  -3.112502161876794
# 12.82  Actual Yield
# 15.362195360535187 41.98668154139433 Average temp/Rain
# 12.919469691770663  Predicted Yield
# Difference =  -0.099469691770663
# 11.8  Actual Yield
# 15.206213308410424 60.13727635766549 Average temp/Rain
# 15.336872639426304  Predicted Yield
# Difference =  -3.536872639426303
# Region 6 Done. Trained with [1 2 3 4 5]
# -2.956689061887205

# %%
gm2 = pystan.StanModel(file='./stan/2d-gaussian.stan')
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_889b1084947e1d379c9ef129719d74d2 NOW.
# C:\Users\Andrew\Anaconda3\lib\site-packages\Cython\Compiler\Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Andrew\AppData\Local\Temp\tmpx2mf9_2y\stanfit4anon_model_889b1084947e1d379c9ef129719d74d2_139835640178124806.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
from numpy import exp,arange
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

loopcounter = 0
Residuals = []
for item in combinations:
    loopcounter +=1 
    templists,rainlists,yieldlist =[],[],[]

    for tempss in item:
        templists.append(np.load('data/Temps'+str(tempss)+'.npy'))

    for rainss in item:
        rainlists.append(np.load('data/Rain'+str(rainss)+'.npy'))

    for yieldss in item:
        yieldlist.append(np.load('data/Yield'+str(yieldss)+'.npy'))

    rainlists = np.array(rainlists)
    templists = np.array(templists)
    yieldlist= np.array(yieldlist)

    templists = templists.reshape(5,int(len(templists[0])/12),12)

    templists= templists[:,:,4:10]

    rainlists = rainlists.reshape(5,int(len(rainlists[0])/12),12)
    rainlists= rainlists[:,:,4:10]

    data2={
        'n_regions':5,
        'n_years':8,
        'd_temp':templists,
        'd_precip':rainlists,
        'd_yields':yieldlist,
        'n_gf':40,
        'temp':np.arange(0,40,1),
        'precip':np.arange(0,200,5)
    }
    fit=gm2.sampling(data=data2,chains=4,iter=1000,verbose=True,seed=1308)


    samples=fit.extract()


    #plt.figure(figsize=(10,10))
    for i in range(0,2000,10):
        plt.plot(fit.data['temp'],samples['fdy1'][i,:],alpha=0.1, c='b')
    plt.xlabel('Temperature')
    plt.ylabel(r'$dy$')
    #plt.title('Growth Curve')
    plt.show()


    #plt.figure(figsize=(10,10))
    for i in range(0,2000,10):
        plt.plot(fit.data['precip'],samples['fdy2'][i,:],alpha=0.1, c='b')
    plt.xlabel('precipitation')
    plt.ylabel(r'$dy$')
    plt.show()
    #plt.title('Growth Curve')



    fig, ax = plt.subplots()


    t1, t2 = 5., 35.
    p1, p2 = 0., 250.
    x = arange(t1,t2,.1)
    y = arange(p1,p2,1.)
    X,Y = meshgrid(x, y) # grid of point
    def yield_equal(temp, precip, mu_t, sigma_t, mu_p, sigma_p, norm):
        """Take six months of T and P and return yield for given params.

        This should be identical to the function in the STAN model
        """
        temp_6m = np.full(6, temp)
        precip_6m = np.full(6, precip)
        if len(norm) == 1:
            norm = norm * np.ones(6)
        dy = np.zeros(6)
        for month in np.arange(6):
            dy[month] = norm[month]*np.exp(-0.5 *( np.square((temp_6m[month]    - mu_t)/sigma_t) 
                                                 + np.square((precip_6m[month] - mu_p)/sigma_p) )
                                          )
        return np.sum(dy)
    def z_func(X,Y):
        return yield_equal(X, Y, float(np.mean(samples['mu_t'])), float(np.mean(samples['sigma_t'])), float(np.mean(samples['mu_p'])),
           float(np.mean(samples['sigma_p'])), [float(np.mean(samples['norm']))])


    z_func = np.vectorize(z_func)
    #Lets use the median

    Z = z_func(X, Y) # evaluation of the function on the grid

    im = imshow(np.flip(Z,axis= 0),cmap="viridis", extent=[t1,t2,p1,p2], aspect="auto") # drawing the function
    # adding the Contour lines with labels
    #cset = contour(Z,arange(-1,1.5,0.2),linewidths=2,cmap=cm.Set2)
    #clabel(cset,inline=True,fmt='%1.1f',fontsize=10)
    cbar = fig.colorbar(im) # adding the colobar on the right
    cbar.set_label('Yield [tonnes ha$^{-1}$]')
    # latex fashion title
    #title('$z=(1-x^2+y^3) e^{-(x^2+y^2)/2}$')

    ax.set_xlabel('T [$^{\circ}$C]')
    ax.set_ylabel('Monthly precipitation (mm)')

    #plt.savefig('./figs/2d_yield_response.pdf')
    #plt.savefig('./figs/2d_yield_response.png')


    z_func = np.vectorize(z_func)
    #Lets use the median

    Z = z_func(X, Y) # evaluation of the function on the grid

    im = ax.imshow(np.flip(Z, axis=0),cmap="viridis", extent=[t1,t2,p1,p2], aspect="auto") # drawing the function

    cbar = fig.colorbar(im) # adding the colobar on the right
    cbar.set_label('Yield [tonnes ha$^{-1}$]')
    # latex fashion title
    #title('$z=(1-x^2+y^3) e^{-(x^2+y^2)/2}$')

    ax.set_xlabel('T (Celsius)')
    ax.set_ylabel('Monthly precipitation (mm)')
    #plt.savefig('./figs/2d_2.pdf')

    plt.show()

    

    TestTemps = np.load('data/Temps'+str(loopcounter)+'.npy')
    TestRains = np.load('data/Rain'+str(loopcounter)+'.npy')
    TestYield = np.load('data/Yield'+str(loopcounter)+'.npy')



    TestRains = np.split(TestRains,len(TestRains)/12)
    TestTemps = np.split(TestTemps,len(TestTemps)/12)

    xindex,yindex = [],[]


    for Rain,Temp,Yield in zip(TestRains,TestTemps,TestYield):

        print(Yield, ' Actual Yield')

        xidx = (np.abs(x - np.mean(Temp[4:10]))).argmin()

        yidx = (np.abs(y - np.mean(Rain[4:10]))).argmin()

        print(np.mean(Temp[4:10]),np.mean(Rain[4:10]), 'Average temp/Rain')
        #print(x[xidx],y[yidx], 'Closest value')
        print(Z[yidx,xidx], ' Predicted Yield')
        print('Difference = ', Yield-Z[yidx,xidx])
        xindex.append(x[xidx])
        yindex.append(y[yidx])
        Residuals.append(Yield-Z[yidx,xidx])
    print('Region',loopcounter, 'Done. Trained with', item)

plt.title('Residuals plot')
plt.scatter(np.arange(1,(8*6)+1),Residuals)
print(np.mean(Residuals))
plt.show()
# Out:
# 7.95  Actual Yield
# 14.414647104349777 54.766995740921494 Average temp/Rain
# 14.190544904298674  Predicted Yield
# Difference =  -6.240544904298674
# 10.51  Actual Yield
# 14.944484391925714 41.961273796518434 Average temp/Rain
# 12.491341693279574  Predicted Yield
# Difference =  -1.9813416932795747
# 12.89  Actual Yield
# 13.998616599742618 69.58885484800027 Average temp/Rain
# 15.04024753036808  Predicted Yield
# Difference =  -2.1502475303680786
# 11.18  Actual Yield
# 14.623573173295455 45.43978041008618 Average temp/Rain
# 12.925844158529147  Predicted Yield
# Difference =  -1.745844158529147
# 12.54  Actual Yield
# 15.33100428710746 63.277669398553265 Average temp/Rain
# 14.972089834761357  Predicted Yield
# Difference =  -2.432089834761358
# 11.69  Actual Yield
# 14.185968893313694 54.55563823988985 Average temp/Rain
# 14.123425189859999  Predicted Yield
# Difference =  -2.4334251898599994
# 11.68  Actual Yield
# 15.50223976964532 48.701213177092306 Average temp/Rain
# 13.497769020147631  Predicted Yield
# Difference =  -1.8177690201476313
# 11.82  Actual Yield
# 15.356184469826596 53.59610287794939 Average temp/Rain
# 14.142615483860435  Predicted Yield
# Difference =  -2.322615483860435
# Region 1 Done. Trained with [2 3 4 5 6]
# 11.5  Actual Yield
# 12.881321782750886 51.98160493688618 Average temp/Rain
# 11.560513354671203  Predicted Yield
# Difference =  -0.06051335467120289
# 13.95  Actual Yield
# 13.112154925132394 61.005736185307825 Average temp/Rain
# 12.876257710558946  Predicted Yield
# Difference =  1.0737422894410535
# 8.66  Actual Yield
# 12.183469928728114 97.20990950997668 Average temp/Rain
# 12.427369790250072  Predicted Yield
# Difference =  -3.767369790250072
# 9.47  Actual Yield
# 13.493582989779258 65.51658264564786 Average temp/Rain
# 13.806689517340262  Predicted Yield
# Difference =  -4.336689517340261
# 13.32  Actual Yield
# 13.588810864841983 55.380299610147354 Average temp/Rain
# 12.676038604722383  Predicted Yield
# Difference =  0.6439613952776178
# 14.88  Actual Yield
# 12.3790636998071 63.443246581933806 Average temp/Rain
# 12.223538798149399  Predicted Yield
# Difference =  2.656461201850602
# 11.82  Actual Yield
# 13.59990382436358 45.38418842095896 Average temp/Rain
# 11.196406612195604  Predicted Yield
# Difference =  0.6235933878043962
# 13.04  Actual Yield
# 13.605862276968063 65.08961631652302 Average temp/Rain
# 13.82125951727026  Predicted Yield
# Difference =  -0.7812595172702608
# Region 2 Done. Trained with [1 3 4 5 6]
# 12.3  Actual Yield
# 11.397465002617087 77.5035100116798 Average temp/Rain
# 13.500964341162657  Predicted Yield
# Difference =  -1.2009643411626563
# 9.46  Actual Yield
# 11.695932647095654 83.13994104979277 Average temp/Rain
# 13.479703439948622  Predicted Yield
# Difference =  -4.019703439948621
# 7.17  Actual Yield
# 10.476859034461926 75.08584734806414 Average temp/Rain
# 12.569707210673624  Predicted Yield
# Difference =  -5.399707210673624
# 7.98  Actual Yield
# 12.279263038324778 58.02672054829355 Average temp/Rain
# 14.026549649125133  Predicted Yield
# Difference =  -6.046549649125133
# 10.58  Actual Yield
# 12.403748316992013 82.26428087049909 Average temp/Rain
# 14.11760538110571  Predicted Yield
# Difference =  -3.5376053811057098
# 10.86  Actual Yield
# 11.301104918511216 78.8301483137592 Average temp/Rain
# 13.346338354331424  Predicted Yield
# Difference =  -2.4863383543314246
# 9.66  Actual Yield
# 12.170730190505772 73.41229519354555 Average temp/Rain
# 14.394991663558185  Predicted Yield
# Difference =  -4.734991663558185
# 11.4  Actual Yield
# 12.316422886833756 88.01444743305717 Average temp/Rain
# 13.497320376530201  Predicted Yield
# Difference =  -2.0973203765302006
# Region 3 Done. Trained with [1 2 4 5 6]
# 11.81  Actual Yield
# 14.085915110009532 53.8150708720396 Average temp/Rain
# 14.755870698866406  Predicted Yield
# Difference =  -2.945870698866406
# 7.59  Actual Yield
# 14.527264359717769 39.463266010503354 Average temp/Rain
# 12.993805090527204  Predicted Yield
# Difference =  -5.403805090527204
# 10.68  Actual Yield
# 13.422502344242611 73.52649934526958 Average temp/Rain
# 14.85327648291407  Predicted Yield
# Difference =  -4.173276482914071
# 10.73  Actual Yield
# 14.45880658787329 55.99576505975614 Average temp/Rain
# 15.000175336774646  Predicted Yield
# Difference =  -4.270175336774646
# 11.15  Actual Yield
# 14.779819007418396 60.17011185874616 Average temp/Rain
# 15.253931534787933  Predicted Yield
# Difference =  -4.103931534787932
# 9.69  Actual Yield
# 13.70231505502669 51.705216022427635 Average temp/Rain
# 14.40837251937778  Predicted Yield
# Difference =  -4.71837251937778
# 11.1  Actual Yield
# 14.779252670434774 51.99145212469265 Average temp/Rain
# 14.66962323505717  Predicted Yield
# Difference =  -3.56962323505717
# 11.66  Actual Yield
# 14.80650772022427 59.22250971806701 Average temp/Rain
# 15.201932547941052  Predicted Yield
# Difference =  -3.5419325479410517
# Region 4 Done. Trained with [1 2 3 5 6]
# 15.1  Actual Yield
# 14.198538275800827 52.94545204909298 Average temp/Rain
# 13.60232663405971  Predicted Yield
# Difference =  1.4976733659402903
# 13.54  Actual Yield
# 14.589825666220515 43.137771619386164 Average temp/Rain
# 11.887439761727128  Predicted Yield
# Difference =  1.652560238272871
# 11.4  Actual Yield
# 14.065022841433363 81.8528400594001 Average temp/Rain
# 16.058463685474813  Predicted Yield
# Difference =  -4.658463685474812
# 10.91  Actual Yield
# 14.548827744717196 58.921625219466584 Average temp/Rain
# 14.70611374515702  Predicted Yield
# Difference =  -3.7961137451570206
# 10.41  Actual Yield
# 15.198138412051868 59.23050963161179 Average temp/Rain
# 14.904756301665442  Predicted Yield
# Difference =  -4.494756301665442
# 10.71  Actual Yield
# 14.073413018917192 63.610225565641485 Average temp/Rain
# 15.12223026932494  Predicted Yield
# Difference =  -4.4122302693249384
# 10.71  Actual Yield
# 15.270283108698948 41.85423852542796 Average temp/Rain
# 11.811409147427929  Predicted Yield
# Difference =  -1.101409147427928
# 10.57  Actual Yield
# 15.18030497476313 58.883721533506936 Average temp/Rain
# 14.904756301665442  Predicted Yield
# Difference =  -4.334756301665442
# Region 5 Done. Trained with [1 2 3 4 6]
# 9.92  Actual Yield
# 14.358576031711706 51.07441986976094 Average temp/Rain
# 13.865065255318978  Predicted Yield
# Difference =  -3.945065255318978
# 9.97  Actual Yield
# 14.732916462941553 40.66096251814372 Average temp/Rain
# 12.22970215253937  Predicted Yield
# Difference =  -2.2597021525393686
# 11.4  Actual Yield
# 13.947335751373886 73.02363248258295 Average temp/Rain
# 15.574269306397575  Predicted Yield
# Difference =  -4.174269306397575
# 10.62  Actual Yield
# 14.567919942128436 50.78099782548899 Average temp/Rain
# 13.910776559258998  Predicted Yield
# Difference =  -3.2907765592589993
# 12.79  Actual Yield
# 15.239959757321992 66.18021898889897 Average temp/Rain
# 15.580605672079923  Predicted Yield
# Difference =  -2.7906056720799235
# 10.75  Actual Yield
# 14.083599775507329 51.59559642377991 Average temp/Rain
# 13.904716027707934  Predicted Yield
# Difference =  -3.1547160277079342
# 12.82  Actual Yield
# 15.362195360535187 41.98668154139433 Average temp/Rain
# 12.380209426203214  Predicted Yield
# Difference =  0.43979057379678643
# 11.8  Actual Yield
# 15.206213308410424 60.13727635766549 Average temp/Rain
# 15.073678375548614  Predicted Yield
# Difference =  -3.273678375548613
# Region 6 Done. Trained with [1 2 3 4 5]
# -2.6962216292604553
