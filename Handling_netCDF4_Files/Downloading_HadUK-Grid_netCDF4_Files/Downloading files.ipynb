# %%
from ftplib import FTP
import fnmatch
import os
from netCDF4 import Dataset
import numpy as np
import pandas as pd
import os 
from astropy.table import Table,Column




# Connecting to FTP server. Email for password.

ftp = FTP('ftp1.ceda.ac.uk')
ftp.login(user='abowell', passwd = 'xxxxxx', )





# Use this link to find data: http://data.ceda.ac.uk/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.0.0/1km


# Here are some different directory paths on the FTP server for rainfall and temps


#Rainfall - Daily average 1x1km
#ftp.cwd('/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.0.0/1km/rainfall/day/v20181126')

#Temp - Monthly Average 1x1km
#ftp.cwd('/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.0.0/1km/tas/mon/v20181126')


#Temp - Daily Max 1x1km
ftp.cwd('/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.0.0/1km/tasmax/day/v20181126')



# Adds all files found that match critera and adds to list



files = []
try:
    files = ftp.nlst()
except (ftplib.error_perm, resp):
    if str(resp) == "550 No files found":
        print ("No files in this directory")
    else:
        raise
otherfiles = [] 
for name in files:
    # This is the critera... the years can be picked etc. Follow link above to find file names
    if fnmatch.fnmatch(name,"*tasmax_hadukgrid_uk_1km_day_20*nc"):
        otherfiles.append(name)
        




#Monthly Average temperature 1km resolution
#ftp.cwd('/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.0.0/1km/tas/mon/v20181126')


# Loops through all files in the list and downloads them to wherever specified 

counter = 0
for item in otherfiles:
    ftp = FTP('ftp1.ceda.ac.uk')
    ftp.login(user='abowell', passwd = 'xxxxxx', )

    #Daily rainfall with 1km resolution 
    #ftp.cwd('/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.0.0/1km/rainfall/day/v20181126')

    #Monthly Average Temp
    #ftp.cwd('/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.0.0/1km/tas/mon/v20181126')
    
    #Temp - Daily Max 1x1km
    ftp.cwd('/badc/ukmo-hadobs/data/insitu/MOHC/HadOBS/HadUK-Grid/v1.0.0.0/1km/tasmax/day/v20181126')
    
    
    # Specify download location here
    
    localfile = open('D:/DailyMaxTemp/'+item, 'wb')
    ftp.retrbinary('RETR ' + item, localfile.write, 1024)
    counter += 1
    print('File ', item,'is downloaded. \n' , counter,' out of ', len(otherfiles)-97)
    localfile.close()
